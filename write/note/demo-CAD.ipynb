# %%
# dependencies
import re
import pandas as pd

# %%
# support methods

# %%
# main
raw = pd.read_parquet("../../individual/CAD/import/output/cad.parquet")
data = pd.read_parquet("../../individual/CAD/export/output/cad.parquet")

# %%
datecols = [col for col in data.columns if 'date' in col]
assert 'occurrence_date_pt' in datecols
assert data.occurrence_date_pt.dtype == '<M8[ns]'

# %% [markdown]
# # Preview random record

# %%
data.sample().T
# Out:
#                                                                305573
# record_id                                                     7585315
# call_type                                                         ADV
# description                                             ADVISED ENTRY
# report_created                                                      N
# location                                                23XX 10TH AVE
# police_district                                                     4
# beat                                                               4A
# day_of_week                                                       Sat
# cleared_by                                                          L
# cleared_by_desc     AUTOMATICALLY                               (f...
# occurrence_date_pt                                2019-07-27 04:19:00
# received_date_pt                                  2019-07-27 04:19:00
# dispatch_date_pt                                                  NaT
# enroute_date_pt                                                   NaT
# at_scene_date_pt                                                  NaT
# clear_date_pt                                     2019-07-27 04:21:00
# objectid                                                       305574
# x                                                      6709112.687687
# y                                                      1959580.039698
# fileyear                                                         2019
# fileid                                                       a933a917
# filename            Sacramento_Call_for_Service_Data_2019_-7220233...

# %% [markdown]
# # Date range of records

# %%
data[datecols].min()
# Out:
# occurrence_date_pt   2019-01-01 00:00:00
# received_date_pt     2019-01-01 00:00:00
# dispatch_date_pt     2019-01-01 00:00:01
# enroute_date_pt      2019-01-01 00:00:01
# at_scene_date_pt     2019-01-01 00:00:01
# clear_date_pt        2019-01-01 00:03:00
# dtype: datetime64[ns]

# %%
data[datecols].max()
# Out:
# occurrence_date_pt   2024-07-09 23:58:00
# received_date_pt     2024-07-09 23:58:00
# dispatch_date_pt     2024-07-10 12:02:58
# enroute_date_pt      2024-07-10 12:02:58
# at_scene_date_pt     2024-07-10 12:20:20
# clear_date_pt        2024-07-16 16:05:00
# dtype: datetime64[ns]

# %% [markdown]
# # Rate of created reports

# %% [markdown]
# ### overall

# %%
vc = data.report_created.value_counts(
    ).to_frame().reset_index()
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#   report_created      count
# 0              N  1,815,447
# 1              Y    273,288

# %%
vc = data.report_created.value_counts(normalize=True
    ).to_frame().reset_index()
vc['proportion'] = vc['proportion'].apply(lambda x: f"{x*100:.1f}%")
vc
# Out:
#   report_created proportion
# 0              N      86.9%
# 1              Y      13.1%

# %% [markdown]
# ### by `description`

# %%
vc = data[['report_created', 'description']].value_counts(
    ).to_frame().reset_index(
    ).head(30)
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#    report_created                                  description    count
# 0               N                          DISTURBANCE-CLARIFY  248,932
# 1               N                                ADVISED ENTRY  166,099
# 2               N                                 TRAFFIC STOP  147,036
# 3               N                          ALL UNITS BROADCAST  138,262
# 4               N                   INCOMPLETE CALL FOR POLICE  114,175
# 5               N                                WELFARE CHECK  104,266
# 6               N  SUSPICIOUS SUBJECT/CIRCUMSTANCE-IN PROGRESS   67,469
# 7               N                ALARM-SECURE NO EVID OF CRIME   46,574
# 8               N                  SUSPICIOUS VEHICLE-OCCUPIED   41,805
# 9               N                                       ERRAND   37,013
# 10              N    DISTURBANCE-DOMESTIC VIOLENCE-VERBAL ONLY   34,444
# 11              N                                 SUBJECT STOP   29,384
# 12              N                           DISTURBANCE-FAMILY   25,540
# 13              N                                 ALARM-CANCEL   25,231
# 14              N      VEHICLE ACCIDENT-NO OR UNKNOWN INJURIES   24,928
# 15              N                              CHECK ON HAZARD   24,812
# 16              N                          CSI REQUEST-CLARIFY   24,640
# 17              N                            DISTURBANCE-NOISE   22,473
# 18              N                             ALARM-ACCIDENTAL   22,019
# 19              N                  ALARM ADVISED-FULL RESPONSE   20,767
# 20              N                  MEDICAL AID-CLARIFY IN TEXT   20,217
# 21              N              MISDEMEANOR ASSAULT-IN PROGRESS   19,285
# 22              Y                          DISTURBANCE-CLARIFY   18,731
# 23              N                     URGENT TELEPHONE MESSAGE   18,270
# 24              N                OPERATIONAL OUTLINE/GAME PLAN   17,886
# 25              N                      SUPPLEMENTAL EMPLOYMENT   17,078
# 26              Y                     REPORT NUMBER ASSIGNMENT   16,928
# 27              Y                        STOLEN VEHICLE-REPORT   16,919
# 28              N                               BUSINESS CHECK   16,518
# 29              N                     REPORT NUMBER ASSIGNMENT   16,381

# %% [markdown]
# ### by cleared description

# %%
vc = data[['report_created', 'cleared_by_desc']].value_counts(
    ).to_frame().reset_index()
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#    report_created                                    cleared_by_desc  \
# 0               N                    POLICE MATTER RESOLVED AT SCENE
# 1               N                                             CANCEL
# 2               Y                    POLICE MATTER RESOLVED AT SCENE
# 3               N  AUTOMATICALLY                               (f...
# 4               N                                   TRAFFIC CITATION
# 5               N                               OTHER/OUTSIDE AGENCY
# 6               Y                               OTHER/OUTSIDE AGENCY
# 7               Y                                            PENDING
# 8               Y                               MISDEMEANOR CITATION
# 9               Y  AUTOMATICALLY                               (f...
# 10              N                                            PENDING
# 11              Y                                   TRAFFIC CITATION
# 12              Y                                             CANCEL
# 13              N                              CIVIL MATTER/REFERRED
# 14              N                               MISDEMEANOR CITATION
# 15              N       HOMELESS RELATED/CANCELLED PRIOR TO DISPATCH
# 16              Y                           DETECTIVE MATTER HANDLED
# 17              N                           DETECTIVE MATTER HANDLED
# 18              Y                                          RESOURCES
# 19              N                                          RESOURCES
# 20              Y       HOMELESS RELATED/CANCELLED PRIOR TO DISPATCH
# 21              Y                              CIVIL MATTER/REFERRED
#
#         count
# 0   1,022,102
# 1     501,114
# 2     220,482
# 3     219,267
# 4      37,467
# 5      30,648
# 6      27,122
# 7      13,163
# 8       4,277
# 9       3,806
# 10      3,367
# 11      2,746
# 12      1,287
# 13        436
# 14        397
# 15        369
# 16        282
# 17        187
# 18         93
# 19         91
# 20         20
# 21         10

# %% [markdown]
# ### by `description` and `cleared_by_desc`

# %%
vc = data[['report_created', 'description', 'cleared_by_desc']].value_counts(
    ).to_frame().reset_index(
    ).head(10)
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#   report_created                                  description  \
# 0              N                          DISTURBANCE-CLARIFY
# 1              N                                ADVISED ENTRY
# 2              N                          ALL UNITS BROADCAST
# 3              N                                 TRAFFIC STOP
# 4              N                                WELFARE CHECK
# 5              N                   INCOMPLETE CALL FOR POLICE
# 6              N                          DISTURBANCE-CLARIFY
# 7              N  SUSPICIOUS SUBJECT/CIRCUMSTANCE-IN PROGRESS
# 8              N                   INCOMPLETE CALL FOR POLICE
# 9              N                ALARM-SECURE NO EVID OF CRIME
#
#                                      cleared_by_desc    count
# 0                    POLICE MATTER RESOLVED AT SCENE  182,419
# 1  AUTOMATICALLY                               (f...  161,961
# 2                                             CANCEL  131,384
# 3                    POLICE MATTER RESOLVED AT SCENE  112,450
# 4                    POLICE MATTER RESOLVED AT SCENE   77,489
# 5                                             CANCEL   65,433
# 6                                             CANCEL   64,943
# 7                    POLICE MATTER RESOLVED AT SCENE   59,950
# 8                    POLICE MATTER RESOLVED AT SCENE   47,558
# 9                    POLICE MATTER RESOLVED AT SCENE   46,497

# %% [markdown]
# # Call types

# %% [markdown]
# ### overall

# %%
vc = data[['call_type', 'description']].value_counts().to_frame().reset_index().head(30)
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#    call_type                                  description    count
# 0        415                          DISTURBANCE-CLARIFY  267,663
# 1        ADV                                ADVISED ENTRY  166,249
# 2      TSTOP                                 TRAFFIC STOP  155,929
# 3         AU                          ALL UNITS BROADCAST  138,445
# 4        952                   INCOMPLETE CALL FOR POLICE  115,360
# 5        981                                WELFARE CHECK  108,328
# 6       927P  SUSPICIOUS SUBJECT/CIRCUMSTANCE-IN PROGRESS   74,192
# 7     ALMSEC                ALARM-SECURE NO EVID OF CRIME   46,746
# 8        971                  SUSPICIOUS VEHICLE-OCCUPIED   45,540
# 9       992E                                       ERRAND   38,923
# 10     415DV    DISTURBANCE-DOMESTIC VIOLENCE-VERBAL ONLY   38,677
# 11     SSTOP                                 SUBJECT STOP   34,743
# 12    RPTNUM                     REPORT NUMBER ASSIGNMENT   33,309
# 13       901      VEHICLE ACCIDENT-NO OR UNKNOWN INJURIES   31,680
# 14      415F                           DISTURBANCE-FAMILY   27,671
# 15       983                              CHECK ON HAZARD   26,442
# 16    ALMCAN                                 ALARM-CANCEL   25,247
# 17       CSI                          CSI REQUEST-CLARIFY   24,670
# 18    503RPT                        STOLEN VEHICLE-REPORT   23,107
# 19      901A                    VEHICLE ACCIDENT-INJURIES   22,681
# 20      242P              MISDEMEANOR ASSAULT-IN PROGRESS   22,619
# 21      415E                            DISTURBANCE-NOISE   22,586
# 22    ALMACC                             ALARM-ACCIDENTAL   22,038
# 23       945                  MEDICAL AID-CLARIFY IN TEXT   22,005
# 24    ALMADV                  ALARM ADVISED-FULL RESPONSE   20,771
# 25        GP                OPERATIONAL OUTLINE/GAME PLAN   19,513
# 26      914E                     URGENT TELEPHONE MESSAGE   18,342
# 27    SUPEMP                      SUPPLEMENTAL EMPLOYMENT   17,315
# 28        BC                               BUSINESS CHECK   16,928
# 29       972                       AT-RISK MISSING PERSON   16,489

# %% [markdown]
# ### SHOTSPOTTER

# %%
shotspotter = data.description.str.contains("SHOTSPOTTER",)

# %%
vc = data.loc[shotspotter, ['description',
                       'report_created',
                       'cleared_by_desc']
].value_counts().to_frame().reset_index()
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#    description report_created  \
# 0  SHOTSPOTTER              N
# 1  SHOTSPOTTER              Y
# 2  SHOTSPOTTER              N
# 3  SHOTSPOTTER              N
# 4  SHOTSPOTTER              Y
# 5  SHOTSPOTTER              Y
# 6  SHOTSPOTTER              N
#
#                                      cleared_by_desc  count
# 0                    POLICE MATTER RESOLVED AT SCENE  2,990
# 1                    POLICE MATTER RESOLVED AT SCENE  1,057
# 2                                             CANCEL    874
# 3                               OTHER/OUTSIDE AGENCY     14
# 4                                             CANCEL      3
# 5                               MISDEMEANOR CITATION      3
# 6  AUTOMATICALLY                               (f...      2

# %%
shotspotter_rate = f"The data indicate there was a `report_created` for \
{data.loc[shotspotter, 'report_created'
].value_counts(normalize=True)['Y']*100:.1f}% of ShotSpotter events \
({data.loc[shotspotter, 'report_created'
].value_counts()['Y']:,} of {shotspotter.sum():,} records). "

overall_rate = f"The data indicate there was a `report_created` for \
{data.report_created.value_counts(normalize=True)['Y']*100:.1f}% of all events \
({data.report_created.value_counts()['Y']:,} of {data.shape[0]:,} records)."

print(shotspotter_rate)
print(overall_rate)
# Out:
# The data indicate there was a `report_created` for 21.5% of ShotSpotter events (1,063 of 4,943 records).
# The data indicate there was a `report_created` for 13.1% of all events (273,288 of 2,088,735 records).

# %%
shotspotter_rate = f"There is a reported `at_scene_date_pt` for \
{data.loc[shotspotter, 'at_scene_date_pt'
].notna().value_counts(normalize=True)[True]*100:.1f}% of ShotSpotter events \
({data.loc[shotspotter, 'at_scene_date_pt'
].notna().value_counts()[True]:,} of {shotspotter.sum():,} records). "

overall_rate = f"There is a reported `at_scene_date_pt` for \
{data.at_scene_date_pt.notna().value_counts(normalize=True)[True]*100:.1f}% of all events \
({data.at_scene_date_pt.notna().value_counts()[True]:,} of {data.shape[0]:,} records)."

print(shotspotter_rate)
print(overall_rate)
# Out:
# There is a reported `at_scene_date_pt` for 82.0% of ShotSpotter events (4,053 of 4,943 records).
# There is a reported `at_scene_date_pt` for 60.6% of all events (1,265,733 of 2,088,735 records).

# %%
data.loc[data.description.str.contains("SHOT", flags=re.I),
'description'].value_counts()
# Out:
# description
# SHOTS FIRED - LESS THAN 15 AGO    13043
# SHOTSPOTTER                        4943
# Name: count, dtype: int64

# %% [markdown]
# ### What would it look like for actual gunfire to have been identified/reported in one of these events?

# %%
vc = data.loc[data.description.str.contains("SHOT", flags=re.I),
['report_created', 'description', 'cleared_by_desc']].value_counts().to_frame().reset_index()
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#    report_created                     description  \
# 0               N  SHOTS FIRED - LESS THAN 15 AGO
# 1               N  SHOTS FIRED - LESS THAN 15 AGO
# 2               N                     SHOTSPOTTER
# 3               Y                     SHOTSPOTTER
# 4               N                     SHOTSPOTTER
# 5               Y  SHOTS FIRED - LESS THAN 15 AGO
# 6               N  SHOTS FIRED - LESS THAN 15 AGO
# 7               Y  SHOTS FIRED - LESS THAN 15 AGO
# 8               N                     SHOTSPOTTER
# 9               N  SHOTS FIRED - LESS THAN 15 AGO
# 10              Y                     SHOTSPOTTER
# 11              Y                     SHOTSPOTTER
# 12              N  SHOTS FIRED - LESS THAN 15 AGO
# 13              N                     SHOTSPOTTER
# 14              N  SHOTS FIRED - LESS THAN 15 AGO
#
#                                       cleared_by_desc  count
# 0                                              CANCEL  6,819
# 1                     POLICE MATTER RESOLVED AT SCENE  5,776
# 2                     POLICE MATTER RESOLVED AT SCENE  2,990
# 3                     POLICE MATTER RESOLVED AT SCENE  1,057
# 4                                              CANCEL    874
# 5                     POLICE MATTER RESOLVED AT SCENE    350
# 6   AUTOMATICALLY                               (f...     65
# 7                                              CANCEL     18
# 8                                OTHER/OUTSIDE AGENCY     14
# 9                                OTHER/OUTSIDE AGENCY     12
# 10                                             CANCEL      3
# 11                               MISDEMEANOR CITATION      3
# 12                                   TRAFFIC CITATION      2
# 13  AUTOMATICALLY                               (f...      2
# 14                                            PENDING      1

# %%
data.loc[data.cleared_by_desc.str.contains("automatically", na=False, flags=re.I),
'cleared_by_desc'].value_counts()
# Out:
# cleared_by_desc
# AUTOMATICALLY                               (for advised entries)    223073
# Name: count, dtype: int64

# %% [markdown]
# #### Outstanding questions
# - "MISDEMEANOR CITATION"? Or "POLICE MATTER RESOLVED AT SCENE"? Some of these appear to have had a report created.
#     - If "POLICE MATTER RESOLVED AT SCENE" with a `report_created` can include actual gunfire, what would that mean about how "RESOLVED" is used in this label? And in others? (seems a little too hand-wavy or protective over key details about distinct scenarios)
# - What warrants "CANCEL"? Or an "AUTOMATICALLY" cleared event "(for advised entries)"?
# - "POLICE MATTER RESOLVED AT SCENE"?
# - All the "SHOTS FIRED" calls include the phrase "LESS THAN 15 AGO." What's that about?

# %% [markdown]
# ### Missing persons

# %%
missper = data.description.str.contains("MISSING PERSON")

# %%
vc = data.loc[missper, ['description',
                       'report_created',
                       'cleared_by_desc']
].value_counts().to_frame().reset_index()
vc['count'] = vc['count'].apply(lambda x: f"{x:,}")
vc
# Out:
#                     description report_created  \
# 0        AT-RISK MISSING PERSON              N
# 1        AT-RISK MISSING PERSON              N
# 2   MISSING PERSON-FAXED REPORT              Y
# 3   MISSING PERSON-FAXED REPORT              Y
# 4         MISSING PERSON-REPORT              Y
# 5        AT-RISK MISSING PERSON              Y
# 6         MISSING PERSON-REPORT              Y
# 7        AT-RISK MISSING PERSON              Y
# 8        AT-RISK MISSING PERSON              N
# 9         MISSING PERSON-REPORT              N
# 10        MISSING PERSON-REPORT              N
# 11        MISSING PERSON-REPORT              Y
# 12        MISSING PERSON-REPORT              Y
# 13        MISSING PERSON-REPORT              N
# 14       AT-RISK MISSING PERSON              Y
# 15       AT-RISK MISSING PERSON              Y
# 16       AT-RISK MISSING PERSON              N
# 17       AT-RISK MISSING PERSON              Y
# 18        MISSING PERSON-REPORT              N
# 19       AT-RISK MISSING PERSON              N
# 20  MISSING PERSON-FAXED REPORT              N
# 21  MISSING PERSON-FAXED REPORT              N
# 22        MISSING PERSON-REPORT              Y
# 23  MISSING PERSON-FAXED REPORT              Y
# 24        MISSING PERSON-REPORT              N
# 25        MISSING PERSON-REPORT              Y
# 26       AT-RISK MISSING PERSON              Y
# 27  MISSING PERSON-FAXED REPORT              Y
# 28        MISSING PERSON-REPORT              N
# 29  MISSING PERSON-FAXED REPORT              N
# 30        MISSING PERSON-REPORT              Y
# 31        MISSING PERSON-REPORT              Y
# 32  MISSING PERSON-FAXED REPORT              N
# 33       AT-RISK MISSING PERSON              Y
# 34  MISSING PERSON-FAXED REPORT              Y
# 35        MISSING PERSON-REPORT              N
# 36  MISSING PERSON-FAXED REPORT              Y
# 37       AT-RISK MISSING PERSON              Y
# 38       AT-RISK MISSING PERSON              N
# 39       AT-RISK MISSING PERSON              N
# 40  MISSING PERSON-FAXED REPORT              Y
#
#                                       cleared_by_desc  count
# 0                     POLICE MATTER RESOLVED AT SCENE  5,812
# 1                                              CANCEL  4,561
# 2                     POLICE MATTER RESOLVED AT SCENE  3,015
# 3                                OTHER/OUTSIDE AGENCY  2,705
# 4                                             PENDING  2,468
# 5                     POLICE MATTER RESOLVED AT SCENE  1,615
# 6                     POLICE MATTER RESOLVED AT SCENE  1,579
# 7                                             PENDING  1,547
# 8                                             PENDING  1,392
# 9                     POLICE MATTER RESOLVED AT SCENE  1,124
# 10                                             CANCEL    947
# 11                               OTHER/OUTSIDE AGENCY    885
# 12  AUTOMATICALLY                               (f...    662
# 13                                            PENDING    617
# 14                               OTHER/OUTSIDE AGENCY    602
# 15  AUTOMATICALLY                               (f...    462
# 16                               OTHER/OUTSIDE AGENCY    252
# 17                                             CANCEL    151
# 18                               OTHER/OUTSIDE AGENCY     88
# 19  AUTOMATICALLY                               (f...     78
# 20                               OTHER/OUTSIDE AGENCY     31
# 21                    POLICE MATTER RESOLVED AT SCENE     31
# 22                                             CANCEL     25
# 23                                             CANCEL     19
# 24  AUTOMATICALLY                               (f...     18
# 25                                          RESOURCES     15
# 26                                          RESOURCES     13
# 27  AUTOMATICALLY                               (f...     11
# 28                              CIVIL MATTER/REFERRED      5
# 29                                             CANCEL      5
# 30       HOMELESS RELATED/CANCELLED PRIOR TO DISPATCH      3
# 31                               MISDEMEANOR CITATION      2
# 32  AUTOMATICALLY                               (f...      2
# 33                                   TRAFFIC CITATION      1
# 34                               MISDEMEANOR CITATION      1
# 35                               MISDEMEANOR CITATION      1
# 36                           DETECTIVE MATTER HANDLED      1
# 37       HOMELESS RELATED/CANCELLED PRIOR TO DISPATCH      1
# 38                               MISDEMEANOR CITATION      1
# 39                              CIVIL MATTER/REFERRED      1
# 40                                            PENDING      1

# %%
data.loc[missper, 'report_created'].value_counts(normalize=True)
# Out:
# report_created
# Y    0.513301
# N    0.486699
# Name: proportion, dtype: float64

# %%
missper_rate = f"The data indicate there was a `report_created` for \
{data.loc[missper, 'report_created'
].value_counts(normalize=True)['Y']*100:.1f}% of MISSING PERSON events \
({data.loc[missper, 'report_created'
].value_counts()['Y']:,} of {missper.sum():,} records). "

overall_rate = f"The data indicate there was a `report_created` for \
{data.report_created.value_counts(normalize=True)['Y']*100:.1f}% of all events \
({data.report_created.value_counts()['Y']:,} of {data.shape[0]:,} records)."

print(missper_rate)
print(overall_rate)
# Out:
# The data indicate there was a `report_created` for 51.3% of MISSING PERSON events (15,784 of 30,750 records).
# The data indicate there was a `report_created` for 13.1% of all events (273,288 of 2,088,735 records).

# %%
missper_rate = f"There is a reported `at_scene_date_pt` for \
{data.loc[missper, 'at_scene_date_pt'
].notna().value_counts(normalize=True)[True]*100:.1f}% of MISSING PERSON events \
({data.loc[missper, 'at_scene_date_pt'
].notna().value_counts()[True]:,} of {missper.sum():,} records). "

overall_rate = f"There is a reported `at_scene_date_pt` for \
{data.at_scene_date_pt.notna().value_counts(normalize=True)[True]*100:.1f}% of all events \
({data.at_scene_date_pt.notna().value_counts()[True]:,} of {data.shape[0]:,} records)."

print(missper_rate)
print(overall_rate)
# Out:
# There is a reported `at_scene_date_pt` for 31.9% of MISSING PERSON events (9,804 of 30,750 records).
# There is a reported `at_scene_date_pt` for 60.6% of all events (1,265,733 of 2,088,735 records).

# %%
data.loc[data.description.str.contains("MISSING", flags=re.I),
'description'].value_counts()
# Out:
# description
# AT-RISK MISSING PERSON         16489
# MISSING PERSON-REPORT           8439
# MISSING PERSON-FAXED REPORT     5822
# Name: count, dtype: int64
